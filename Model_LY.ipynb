# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

from glob import glob

# %%
from tensorflow import keras

# Import of keras model and hidden layers for CNN
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Dense, Flatten, Dropout

#Image handling libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd

#Sklearn libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import matplotlib.pyplot as plt
from matplotlib import style

# %%
import zipfile
with zipfile.ZipFile("/content/drive/MyDrive/ROAD SURFACE.zip","r") as zip_ref:
    zip_ref.extractall("/content/drive/MyDrive/ROAD SURFACE")

# %%
import os

data = os.path.dirname(r"/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/")

# %%
ImagePaths = []
for image in list(os.listdir(data)):
        ImagePaths=ImagePaths+[data+"/"+image]
ImagePaths
# Out:
# ['/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/Final',
#  '/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/normal']

# %%
print(len(ImagePaths))
# Out:
# 2

# %%
IMG_SIZE=128
X=[]
y=[]
for image in ImagePaths:
  if "normal" in image:
    for i in os.listdir(image):
      try:
          img = cv2.imread(image+"/"+i,cv2.IMREAD_COLOR)
          img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

          X.append(np.array(img))
          # print(X)
          y.append('NORMAL')
      except:
          pass

  if "Final" in image:

      for i in os.listdir(image):
        try:        
            img = cv2.imread(image+"/"+i,cv2.IMREAD_COLOR)
            img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

            X.append(np.array(img))
            y.append('POTHOLES')
        except:
          pass

# %%
len(y)
# Out:
# 1913

# %%
import random as rn
fig,ax=plt.subplots(2,5)
plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0)
fig.set_size_inches(15,15)

for i in range(2):
    for j in range (5):
        l=rn.randint(0,len(y))
        ax[i,j].imshow(X[l][:,:,::-1])
        ax[i,j].set_title(y[l])
        ax[i,j].set_aspect('equal')

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

le=LabelEncoder()
Y=le.fit_transform(y)
Y=to_categorical(Y,2)
print(Y)
X=np.array(X)
#X=X/255

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=5)
# Out:
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
# Create a CNN Sequential Model
model = Sequential()

model.add(Conv2D(32, (5,5), activation = 'relu', input_shape=(128,128,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3, 3), activation='relu')) 
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu')) 
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu')) 
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu')) 
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dropout(0.4))

model.add(Dense(128, activation='relu'))

model.add(Dense(2, activation='softmax'))

# %%
#Model configuration for training purpose
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 128)         147584
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 455,874
# Trainable params: 455,874
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(x_train, y_train, epochs=30, batch_size=12, verbose=2, 
         validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 120/120 - 61s - loss: 1.0187 - accuracy: 0.8201 - val_loss: 0.2523 - val_accuracy: 0.9165 - 61s/epoch - 507ms/step
# Epoch 2/30
# 120/120 - 59s - loss: 0.4374 - accuracy: 0.8445 - val_loss: 0.5240 - val_accuracy: 0.8351 - 59s/epoch - 493ms/step
# Epoch 3/30
# 120/120 - 57s - loss: 0.3548 - accuracy: 0.8717 - val_loss: 0.4093 - val_accuracy: 0.8747 - 57s/epoch - 474ms/step
# Epoch 4/30
# 120/120 - 59s - loss: 0.3194 - accuracy: 0.8877 - val_loss: 0.2489 - val_accuracy: 0.9019 - 59s/epoch - 492ms/step
# Epoch 5/30
# 120/120 - 57s - loss: 0.3011 - accuracy: 0.8780 - val_loss: 0.3095 - val_accuracy: 0.9061 - 57s/epoch - 475ms/step
# Epoch 6/30
# 120/120 - 59s - loss: 0.2997 - accuracy: 0.8933 - val_loss: 0.2503 - val_accuracy: 0.9228 - 59s/epoch - 490ms/step
# Epoch 7/30
# 120/120 - 57s - loss: 0.2507 - accuracy: 0.9045 - val_loss: 0.3876 - val_accuracy: 0.9207 - 57s/epoch - 473ms/step
# Epoch 8/30
# 120/120 - 59s - loss: 0.2395 - accuracy: 0.9052 - val_loss: 0.2418 - val_accuracy: 0.9269 - 59s/epoch - 490ms/step
# Epoch 9/30
# 120/120 - 59s - loss: 0.2445 - accuracy: 0.9073 - val_loss: 0.3562 - val_accuracy: 0.9248 - 59s/epoch - 494ms/step
# Epoch 10/30
# 120/120 - 57s - loss: 0.2370 - accuracy: 0.9156 - val_loss: 0.2821 - val_accuracy: 0.9102 - 57s/epoch - 472ms/step
# Epoch 11/30
# 120/120 - 57s - loss: 0.2585 - accuracy: 0.9093 - val_loss: 0.2151 - val_accuracy: 0.9353 - 57s/epoch - 473ms/step
# Epoch 12/30
# 120/120 - 59s - loss: 0.2198 - accuracy: 0.9247 - val_loss: 0.2080 - val_accuracy: 0.9311 - 59s/epoch - 492ms/step
# Epoch 13/30
# 120/120 - 59s - loss: 0.2211 - accuracy: 0.9212 - val_loss: 0.1960 - val_accuracy: 0.9415 - 59s/epoch - 493ms/step
# Epoch 14/30
# 120/120 - 57s - loss: 0.2007 - accuracy: 0.9205 - val_loss: 0.1882 - val_accuracy: 0.9436 - 57s/epoch - 477ms/step
# Epoch 15/30
# 120/120 - 57s - loss: 0.2109 - accuracy: 0.9198 - val_loss: 0.2573 - val_accuracy: 0.9311 - 57s/epoch - 475ms/step
# Epoch 16/30
# 120/120 - 59s - loss: 0.2071 - accuracy: 0.9296 - val_loss: 0.1801 - val_accuracy: 0.9374 - 59s/epoch - 492ms/step
# Epoch 17/30
# 120/120 - 60s - loss: 0.1840 - accuracy: 0.9372 - val_loss: 0.3821 - val_accuracy: 0.8831 - 60s/epoch - 498ms/step
# Epoch 18/30
# 120/120 - 58s - loss: 0.2380 - accuracy: 0.9121 - val_loss: 0.2622 - val_accuracy: 0.9081 - 58s/epoch - 479ms/step
# Epoch 19/30
# 120/120 - 59s - loss: 0.1863 - accuracy: 0.9358 - val_loss: 0.1984 - val_accuracy: 0.9374 - 59s/epoch - 495ms/step
# Epoch 20/30
# 120/120 - 57s - loss: 0.1724 - accuracy: 0.9435 - val_loss: 0.2817 - val_accuracy: 0.9165 - 57s/epoch - 476ms/step
# Epoch 21/30
# 120/120 - 59s - loss: 0.1730 - accuracy: 0.9386 - val_loss: 0.2335 - val_accuracy: 0.8956 - 59s/epoch - 493ms/step
# Epoch 22/30
# 120/120 - 57s - loss: 0.1470 - accuracy: 0.9428 - val_loss: 0.2251 - val_accuracy: 0.9374 - 57s/epoch - 476ms/step
# Epoch 23/30
# 120/120 - 59s - loss: 0.1863 - accuracy: 0.9372 - val_loss: 0.2553 - val_accuracy: 0.9061 - 59s/epoch - 493ms/step
# Epoch 24/30
# 120/120 - 59s - loss: 0.1390 - accuracy: 0.9463 - val_loss: 0.3581 - val_accuracy: 0.9311 - 59s/epoch - 495ms/step
# Epoch 25/30
# 120/120 - 57s - loss: 0.1381 - accuracy: 0.9540 - val_loss: 0.2978 - val_accuracy: 0.9436 - 57s/epoch - 476ms/step
# Epoch 26/30
# 120/120 - 57s - loss: 0.1480 - accuracy: 0.9400 - val_loss: 0.3301 - val_accuracy: 0.8580 - 57s/epoch - 476ms/step
# Epoch 27/30
# 120/120 - 59s - loss: 0.1394 - accuracy: 0.9491 - val_loss: 0.1738 - val_accuracy: 0.9395 - 59s/epoch - 493ms/step
# Epoch 28/30
# 120/120 - 59s - loss: 0.1141 - accuracy: 0.9589 - val_loss: 0.2820 - val_accuracy: 0.9144 - 59s/epoch - 492ms/step
# Epoch 29/30
# 120/120 - 57s - loss: 0.1927 - accuracy: 0.9303 - val_loss: 0.2081 - val_accuracy: 0.9269 - 57s/epoch - 476ms/step
# Epoch 30/30
# 120/120 - 57s - loss: 0.2653 - accuracy: 0.8961 - val_loss: 0.2955 - val_accuracy: 0.8998 - 57s/epoch - 475ms/step

# %%
import pickle
saved_model='saved_model.sav'
pickle.dump(model,open(saved_model,'wb'))
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.

# %%
import pickle
loaded_model=pickle.load(open(saved_model,'rb'))

# %%
loss, accuracy = loaded_model.evaluate(x_test, y_test)

print('Test accuracy: {:2.2f}%'.format(accuracy*100))
# Out:
# 15/15 [==============================] - 5s 322ms/step - loss: 0.2955 - accuracy: 0.8998
# Test accuracy: 89.98%

# %%
prediction = loaded_model.predict(x_test)
# Out:
# 15/15 [==============================] - 5s 315ms/step

# %%
y_pred = np.argmax(prediction, axis=1)

# %%
y_test1=y_test.astype(int)
y_test2=[]
for i in y_test1:
    a=1
    #print(i[0],i[1])
    if(i[0]==1 and i[1]==0):
        a=0
    y_test2.append(a)

# %%
pd.DataFrame(confusion_matrix(y_test2, y_pred),
             columns=["Predicted NORMAL", "Predicted POTHOLES"],
             index=["Actual NORMAL", "Actual POTHOLES"])
# Out:
#                  Predicted NORMAL  Predicted POTHOLES
# Actual NORMAL                  60                  27
# Actual POTHOLES                21                 371

# %%
IMG_SIZE=128
epochs=5
batches=32
X=[]
y=[]
filename=[]
for image in ImagePaths:
  if "normal" in image:
    for i in os.listdir(image):
      try:
          img = cv2.imread(image+"/"+i,cv2.IMREAD_COLOR)
          img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

          X.append(np.array(img))
          filename.append(image+"/"+i)
          # print(X)
          y.append('NORMAL')
      except:
          pass

  if "Final" in image:
      for i in os.listdir(image):
        try:
            img = cv2.imread(image+"/"+i,cv2.IMREAD_COLOR)
            img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

            X.append(np.array(img))
            filename.append(image+"/"+i)
            y.append('POTHOLES')
        except:
          pass

# %%
img_df = pd.DataFrame(
    {'filename': filename,
     'y': y
    })

img_df=img_df.sample(frac=1)

# %%
tr_img=img_df[:450]
valid_img=img_df[450:]

# %%
IMAGE_SIZE = [128, 128]
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
folders = glob('/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/' + '/*')
newFolders=[]
for i in folders:
  if ("normal" in i) or ('Final' in i):
    newFolders.append(i)
newFolders
# Out:
# ['/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/Final',
#  '/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/normal']

# %%
# our layers - you can add more if you want
x = Flatten()(vgg.output)
prediction = Dense(len(newFolders), activation='softmax')(x)

# %%
# create a model object
model2 = Model(inputs=vgg.input, outputs=prediction)

# %%
model2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 2)                 16386
#
# =================================================================
# Total params: 14,731,074
# Trainable params: 16,386
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model2.compile(
loss='categorical_crossentropy',
optimizer='rmsprop',
metrics=['accuracy'])

# %%
gen = ImageDataGenerator(
  rotation_range=20,
  width_shift_range=0.1,
  height_shift_range=0.1,
  shear_range=0.1,
  zoom_range=0.2,
  horizontal_flip=True,
  vertical_flip=True,
  preprocessing_function=preprocess_input
)

# %%
test_gen = gen.flow_from_dataframe(
        dataframe=img_df,
        x_col="filename",
        y_col="y",
        target_size=IMAGE_SIZE)
print(test_gen.class_indices)
# Out:
# Found 1913 validated image filenames belonging to 2 classes.
# {'NORMAL': 0, 'POTHOLES': 1}

# %%
labels = [None] * len(test_gen.class_indices)
for k, v in test_gen.class_indices.items():
  labels[v] = k

# %%
try:
    for x, y in test_gen:
      print("min:", x[0].min(), "max:", x[0].max())
      plt.title(labels[np.argmax(y[0])])
      plt.imshow(x[0])
      plt.show()
      break
except:
    pass
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min: -90.17242 max: 72.230064

# %%
train_path = '/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/'
train_generator = gen.flow_from_dataframe(
        dataframe=tr_img,
        x_col="filename",
        y_col="y",
        target_size=IMAGE_SIZE,
        shuffle=True,
      batch_size=batches)

valid_generator = gen.flow_from_dataframe(
        dataframe=valid_img,
        x_col="filename",
        y_col="y",
        target_size=IMAGE_SIZE,
        shuffle=True,
      batch_size=batches)
# Out:
# Found 450 validated image filenames belonging to 2 classes.
# Found 1463 validated image filenames belonging to 2 classes.

# %%
train_img_path = '/content/drive/MyDrive/ROAD SURFACE/ROAD SURFACE/Road Surface Image/Paved Road/Pothole in Rainy Season/' + '/*/*.j*'
# fit the model
try:
    r = model.fit_generator(
          train_generator,
          validation_data=valid_generator,
          epochs=epochs,
          steps_per_epoch=len(image_files) // batches,
          validation_steps=len(valid_image_files) // batches)
except:
    pass
